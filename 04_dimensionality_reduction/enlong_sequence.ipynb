# %%
import numpy as np
import os

import shutil
def mycopyfile(srcfile,dstpath):                       
    if not os.path.isfile(srcfile):
        print ("%s not exist!"%(srcfile))
    else:
        fpath,fname=os.path.split(srcfile)             
        #if not os.path.exists(dstpath):
            #os.makedirs(dstpath)                       
        shutil.copy(srcfile, dstpath)          
        print ("copy %s -> %s"%(srcfile, dstpath))

path1 = 'C:/Users/Administrator/Desktop/res_lstm2'
folder_list = os.listdir(path1)
for folder in folder_list:
    thickness = folder.split('_')[2]
    u = folder.split('_')[3]
    path2 = os.path.join(path1,folder)
    filename = thickness+'_'+u+'_coo_7.ply'
    path3 = os.path.join(path2,filename)
    #print(path3)
    for j in range(8,13,1):
        filename2 = thickness+'_'+u+'_coo_'+str(j)+'.ply'
        path4 = os.path.join(path2,filename2)
        #print(path4)
        mycopyfile(path3,path4)
# Out:
# copy C:/Users/Administrator/Desktop/res_lstm2\res_f_0.008_u0825\0.008_u0825_coo_7.ply -> C:/Users/Administrator/Desktop/res_lstm2\res_f_0.008_u0825\0.008_u0825_coo_8.ply
# copy C:/Users/Administrator/Desktop/res_lstm2\res_f_0.008_u0825\0.008_u0825_coo_7.ply -> C:/Users/Administrator/Desktop/res_lstm2\res_f_0.008_u0825\0.008_u0825_coo_9.ply
# copy C:/Users/Administrator/Desktop/res_lstm2\res_f_0.008_u0825\0.008_u0825_coo_7.ply -> C:/Users/Administrator/Desktop/res_lstm2\res_f_0.008_u0825\0.008_u0825_coo_10.ply
# copy C:/Users/Administrator/Desktop/res_lstm2\res_f_0.008_u0825\0.008_u0825_coo_7.ply -> C:/Users/Administrator/Desktop/res_lstm2\res_f_0.008_u0825\0.008_u0825_coo_11.ply
# copy C:/Users/Administrator/Desktop/res_lstm2\res_f_0.008_u0825\0.008_u0825_coo_7.ply -> C:/Users/Administrator/Desktop/res_lstm2\res_f_0.008_u0825\0.008_u0825_coo_12.ply
# ...
