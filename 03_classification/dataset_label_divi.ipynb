# %%
import os, shutil

original_dataset_dir = 'C:/Users/Administrator/Desktop/brain_code/03_classification/dataset_label'
base_dir = 'C:/Users/Administrator/Desktop/brain_code/03_classification/dataset_label_division'

os.mkdir(base_dir)
train_dir = os.path.join(base_dir, 'mor_train')
os.mkdir(train_dir)
validation_dir = os.path.join(base_dir, 'mor_validation')
os.mkdir(validation_dir)
test_dir = os.path.join(base_dir,'mor_test')
os.mkdir(test_dir)

train_0_dir = os.path.join(train_dir,'0')
os.mkdir(train_0_dir)
train_1_dir = os.path.join(train_dir,'1')
os.mkdir(train_1_dir)
train_2_dir = os.path.join(train_dir,'2')
os.mkdir(train_2_dir)
train_3_dir = os.path.join(train_dir,'3')
os.mkdir(train_3_dir)

validation_0_dir = os.path.join(validation_dir,'0')
os.mkdir(validation_0_dir)
validation_1_dir = os.path.join(validation_dir,'1')
os.mkdir(validation_1_dir)
validation_2_dir = os.path.join(validation_dir,'2')
os.mkdir(validation_2_dir)
validation_3_dir = os.path.join(validation_dir,'3')
os.mkdir(validation_3_dir)

test_0_dir = os.path.join(test_dir,'0')
os.mkdir(test_0_dir)
test_1_dir = os.path.join(test_dir,'1')
os.mkdir(test_1_dir)
test_2_dir = os.path.join(test_dir,'2')
os.mkdir(test_2_dir)
test_3_dir = os.path.join(test_dir,'3')
os.mkdir(test_3_dir)

# %%
import random

random.seed(726)

data_0_dir = 'C:/Users/Administrator/Desktop/brain_code/03_classification/dataset_label/0'
filepaths =os.listdir(data_0_dir)
random.shuffle(filepaths)
num = 1
for i in range(len(filepaths)):
    filename = filepaths[i]
    if(num<=6):
        src = os.path.join(data_0_dir,filename)
        dst = os.path.join(train_0_dir,filename)
        shutil.copyfile(src, dst)
    elif(num>12):
        src = os.path.join(data_0_dir,filename)
        dst = os.path.join(test_0_dir,filename)
        shutil.copyfile(src, dst)
    else:
        src = os.path.join(data_0_dir,filename)
        dst = os.path.join(validation_0_dir,filename)
        shutil.copyfile(src, dst)

    num += 1

data_1_dir = 'C:/Users/Administrator/Desktop/brain_code/03_classification/dataset_label/1'
filepaths =os.listdir(data_1_dir)
random.shuffle(filepaths)
num = 1
for i in range(len(filepaths)):
    filename = filepaths[i]
    if(num<=4):
        src = os.path.join(data_1_dir,filename)
        dst = os.path.join(train_1_dir,filename)
        shutil.copyfile(src, dst)
    elif(num>7):
        src = os.path.join(data_1_dir,filename)
        dst = os.path.join(test_1_dir,filename)
        shutil.copyfile(src, dst)
    else:
        src = os.path.join(data_1_dir,filename)
        dst = os.path.join(validation_1_dir,filename)
        shutil.copyfile(src, dst)

    num += 1

    
data_2_dir = 'C:/Users/Administrator/Desktop/brain_code/03_classification/dataset_label/2'
filepaths =os.listdir(data_2_dir)
random.shuffle(filepaths)
num = 1
for i in range(len(filepaths)):
    filename = filepaths[i]
    if(num<=6):
        src = os.path.join(data_2_dir,filename)
        dst = os.path.join(train_2_dir,filename)
        shutil.copyfile(src, dst)
    elif(num>12):
        src = os.path.join(data_2_dir,filename)
        dst = os.path.join(test_2_dir,filename)
        shutil.copyfile(src, dst)
    else:
        src = os.path.join(data_2_dir,filename)
        dst = os.path.join(validation_2_dir,filename)
        shutil.copyfile(src, dst)

    num += 1
    
data_3_dir = 'C:/Users/Administrator/Desktop/brain_code/03_classification/dataset_label/3'
filepaths =os.listdir(data_3_dir)
random.shuffle(filepaths)
num = 1
for i in range(len(filepaths)):
    filename = filepaths[i]
    if(num<=5):
        src = os.path.join(data_3_dir,filename)
        dst = os.path.join(train_3_dir,filename)
        shutil.copyfile(src, dst)
    elif(num>10):
        src = os.path.join(data_3_dir,filename)
        dst = os.path.join(test_3_dir,filename)
        shutil.copyfile(src, dst)
    else:
        src = os.path.join(data_3_dir,filename)
        dst = os.path.join(validation_3_dir,filename)
        shutil.copyfile(src, dst)

    num += 1
