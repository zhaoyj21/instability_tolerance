# %%
import os
import numpy as np
path = 'C:/Users/Administrator/Desktop/brain_code/02_cluster/mor_data/'
save_path = 'C:/Users/Administrator/Desktop/brain_code/03_classification/dataset/'
folder_list = os.listdir(path)
folder_list.sort()
for folder in folder_list:
    file_path = path + folder +'/B19000.txt'
    file_data = open(file_path)
    print(file_path)
    data = []
    a = file_data.readlines()[1:8760]
    for i in range(8759):
        data2 = []
        b = a[i].replace("\n","").split(" ")
        c = [float(x) for x in b]
        data2.append(c[0])
        data2.append(c[1])
        data2.append(c[2])
        data.append(data2)
    save_file_path = save_path + folder + '.txt'
    np.savetxt(save_file_path,data)
    print(save_file_path)
# Out:
# C:/Users/Administrator/Desktop/brain_code/02_cluster/mor_data/e_0.022_u1/B19000.txt
# C:/Users/Administrator/Desktop/brain_code/03_classification/dataset/e_0.022_u1.txt
# C:/Users/Administrator/Desktop/brain_code/02_cluster/mor_data/e_0.024_u1/B19000.txt
# C:/Users/Administrator/Desktop/brain_code/03_classification/dataset/e_0.024_u1.txt
# C:/Users/Administrator/Desktop/brain_code/02_cluster/mor_data/e_0.026_u1/B19000.txt
# C:/Users/Administrator/Desktop/brain_code/03_classification/dataset/e_0.026_u1.txt
# C:/Users/Administrator/Desktop/brain_code/02_cluster/mor_data/e_0.028_u1/B19000.txt
# C:/Users/Administrator/Desktop/brain_code/03_classification/dataset/e_0.028_u1.txt
# C:/Users/Administrator/Desktop/brain_code/02_cluster/mor_data/e_0.030_u1/B19000.txt
# C:/Users/Administrator/Desktop/brain_code/03_classification/dataset/e_0.030_u1.txt
# C:/Users/Administrator/Desktop/brain_code/02_cluster/mor_data/e_0.034_u1/B19000.txt
# ...
